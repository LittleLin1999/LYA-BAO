# %%
from scipy.interpolate import interp1d
import itertools
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # planck18_matterpower.dat

# %%
camb = np.genfromtxt('planck18_matterpower.dat')

k = camb[:,0]
pb2d_0 = camb[:,5]
pb2v_0 = camb[:,6]
pb22_0 = camb[:,7]
pbs2d_0 = camb[:,8]
pbs2v_0 = camb[:,9]
pb2s2_0 = camb[:,10]
pbs22_0 = camb[:,11]
pb3nl_0 = camb[:,12]

A = np.full((3,3),None)
A0 = np.full((3,3),None)
A0[0,0],A0[0,1],A0[1,1],A0[1,2],A0[2,2] = camb[:,16:21].T
       
B0 = np.full((4,4,4),None)
B = np.full((4,4,4),None)
B0[0,0,0],B0[0,0,1],B0[0,1,0],B0[0,1,1],\
B0[1,0,0],B0[1,0,1],B0[1,1,0],B0[1,1,1],\
B0[2,0,1],B0[2,1,0],B0[2,1,1],B0[3,1,1] = camb[:,21:33].T


for m,n in itertools.product(range(3),range(3)):
    if A0[m,n] is not None:
        plt.plot(k,A0[m,n])
        plt.title(r'$A_{\rm{%d%d}}$'%(m,n))
        plt.show()
for m,a,b in itertools.product(range(4),range(2),range(2)):
    if B0[m,a,b] is not None:
        plt.plot(k,B0[m,a,b])
        plt.title(r'$B^{\rm{%d}}_{\rm{%d%d}}$'%(m,a,b))
        plt.show()

# %% [markdown]
# # test_nl3_matterpower.dat

# %%
camb = np.genfromtxt('test_nl3_matterpower.dat')

k = camb[:,0]
pb2d_0 = camb[:,5]
pb2v_0 = camb[:,6]
pb22_0 = camb[:,7]
pbs2d_0 = camb[:,8]
pbs2v_0 = camb[:,9]
pb2s2_0 = camb[:,10]
pbs22_0 = camb[:,11]
pb3nl_0 = camb[:,12]

A = np.full((3,3),None)
A0 = np.full((3,3),None)
A0[0,0],A0[0,1],A0[1,1],A0[1,2],A0[2,2] = camb[:,16:21].T
       
B0 = np.full((4,4,4),None)
B = np.full((4,4,4),None)
B0[0,0,0],B0[0,0,1],B0[0,1,0],B0[0,1,1],\
B0[1,0,0],B0[1,0,1],B0[1,1,0],B0[1,1,1],\
B0[2,0,1],B0[2,1,0],B0[2,1,1],B0[3,1,1] = camb[:,21:33].T


for m,n in itertools.product(range(3),range(3)):
    if A0[m,n] is not None:
        plt.plot(k,A0[m,n])
        plt.title(r'$A_{\rm{%d%d}}$'%(m,n))
        plt.show()
for m,a,b in itertools.product(range(4),range(2),range(2)):
    if B0[m,a,b] is not None:
        plt.plot(k,B0[m,a,b])
        plt.title(r'$B^{\rm{%d}}_{\rm{%d%d}}$'%(m,a,b))
        plt.show()

# %% [markdown]
# # test_nl4_matterpower.dat

# %%
camb = np.genfromtxt('test_nl4_matterpower.dat')

k = camb[:,0]
pb2d_0 = camb[:,5]
pb2v_0 = camb[:,6]
pb22_0 = camb[:,7]
pbs2d_0 = camb[:,8]
pbs2v_0 = camb[:,9]
pb2s2_0 = camb[:,10]
pbs22_0 = camb[:,11]
pb3nl_0 = camb[:,12]

A = np.full((3,3),None)
A0 = np.full((3,3),None)
A0[0,0],A0[0,1],A0[1,1],A0[1,2],A0[2,2] = camb[:,16:21].T
       
B0 = np.full((4,4,4),None)
B = np.full((4,4,4),None)
B0[0,0,0],B0[0,0,1],B0[0,1,0],B0[0,1,1],\
B0[1,0,0],B0[1,0,1],B0[1,1,0],B0[1,1,1],\
B0[2,0,1],B0[2,1,0],B0[2,1,1],B0[3,1,1] = camb[:,21:33].T


for m,n in itertools.product(range(3),range(3)):
    if A0[m,n] is not None:
        plt.plot(k,A0[m,n])
        plt.title(r'$A_{\rm{%d%d}}$'%(m,n))
        plt.show()
for m,a,b in itertools.product(range(4),range(2),range(2)):
    if B0[m,a,b] is not None:
        plt.plot(k,B0[m,a,b])
        plt.title(r'$B^{\rm{%d}}_{\rm{%d%d}}$'%(m,a,b))
        plt.show()
